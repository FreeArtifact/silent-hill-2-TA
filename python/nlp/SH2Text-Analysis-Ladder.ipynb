# %% [markdown]
# Silent Hill and Jacobs Ladder Comparative Text Analysis

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import FreqDist
from nltk.text import Text
import matplotlib.pyplot as plt

with open("../../text-files/jacobs-ladder-script.txt", "r", encoding="utf-8") as f:
    jacob_text = f.read()

with open("../../text-files/game-dialogue.txt", "r", encoding="utf-8") as f:
    sh_text = f.read()

jacob_tokens = word_tokenize(jacob_text.lower())
sh_tokens = word_tokenize(sh_text.lower())

# %% [markdown]
# Frequency Distributions

# %%
jacob_freq = FreqDist(jacob_tokens)
sh_freq = FreqDist(sh_tokens)

print("\nTop 20 words in Jacob's Ladder:\n")
print(jacob_freq.most_common(20))

print("\nTop 20 words in Silent Hill 2:\n")
print(sh_freq.most_common(20))
# Out:
# Top 20 words in Jacob's Ladder:
#
# [('.', 3864), ('the', 1774), (',', 1156), ('jacob', 1148), ('a', 847), ('and', 816), ('to', 697), ('it', 619), ('you', 604), ('he', 594), ('of', 593), ('is', 590), ("'s", 545), ('i', 530), ('?', 525), ('his', 507), ('in', 435), ('jezzie', 335), (')', 303), ('(', 302)]
#
# Top 20 words in Silent Hill 2:
#
# [('.', 887), ('the', 587), (':', 556), ('james', 518), ('’', 461), ('i', 378), ('you', 368), (',', 322), ('to', 298), ('...', 278), ('?', 272), ('maria', 255), ('and', 247), ('a', 219), ('it', 193), ('is', 191), ('s', 166), ('!', 150), ('of', 147), ('-', 132)]

# %% [markdown]
# Shared Vocabulary

# %%
jacob_vocab = set(jacob_tokens)
sh_vocab = set(sh_tokens)

common_words = jacob_vocab.intersection(sh_vocab)

print("\nSome shared words:\n")
print(list(common_words)[:50])
# Out:
# Some shared words:
#
# ['nurse', 'some', 'kicking', 'play', 'their', 'dropped', 'enters', 'following', 'won', 'needed', 'between', 'impossible', 'explain', 'blue', 'bodies', 'doing', 'more', 'brother', 'work', 'forever', 'calling', 'beyond', 'bleeding', 'yet', 'light', 'docks', 'black', 'although', 'second', 'honey', 'city', 'girl', 'leg', 'swallows', 'me', 'finds', 'cemetery', '4', 'since', 'nothing', 'she', 'screams', 'eating', 'read', 'attacks', 'looking', 'herself', 'kept', 'let', 'third']

# %% [markdown]
# Themes

# %%
themes = ["nightmare", "death", "suffering", "love", "wife", "hell"]

print("\nTheme counts:\n")
for word in themes:
    print(f"{word}:")
    print("  Jacob:", jacob_freq[word])
    print("  SH2:", sh_freq[word])
# Out:
# Theme counts:
#
# nightmare:
#   Jacob: 2
#   SH2: 3
# death:
#   Jacob: 4
#   SH2: 1
# suffering:
#   Jacob: 8
#   SH2: 1
# love:
#   Jacob: 25
#   SH2: 6
# wife:
#   Jacob: 4
#   SH2: 5
# hell:
#   Jacob: 34
#   SH2: 5

# %% [markdown]
# Dispersion plots

# %%
jacob_text_nltk = Text(jacob_tokens)
sh_text_nltk = Text(sh_tokens)

words_to_track = ["suffering", "death", "hell", "nightmare", "love", "wife"]

print("\nShowing dispersion plot for Jacob's Ladder...")
jacob_text_nltk.dispersion_plot(words_to_track)
plt.show()

print("\nShowing dispersion plot for Silent Hill 2...")
sh_text_nltk.dispersion_plot(words_to_track)
plt.show()
# Out:
# Showing dispersion plot for Jacob's Ladder...
# /Users/ellagalioto/GitHub/silent-hill-2-TA/.venv/lib/python3.12/site-packages/nltk/draw/__init__.py:15: UserWarning: nltk.draw package not loaded (please install Tkinter library).
#   warnings.warn("nltk.draw package not loaded (please install Tkinter library).")
# Showing dispersion plot for Silent Hill 2...
