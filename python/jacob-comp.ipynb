# %%
import os
import nltk
from nltk.corpus import wordnet as wn
from nltk.probability import FreqDist

# %%
with open("../sources/game-dialogue.txt") as file:
    raw_text = file.read()
    tokens = raw_text.split()
    tokens = [w.lower() for w in tokens]
    # text object
    textObj = nltk.Text(tokens)

    #nltk.download('stopwords')
    stopwords = nltk.corpus.stopwords.words('english')
    filtered_tokens = [w for w in tokens if w.isalpha() and w not in stopwords]

    fdist = FreqDist(filtered_tokens)
    print(fdist)
    print(fdist.most_common(20))
    
    print(80*"=")
    print(f"Concordance of 'Begins':")
    textObj.concordance("begins")
# Out:
# <FreqDist with 1019 samples and 3926 outcomes>
# [('james', 198), ('maria', 99), ('room', 48), ('walks', 40), ('mary', 39), ('begins', 38), ('laura', 35), ('eddie', 33), ('know', 33), ('way', 32), ('looks', 31), ('little', 30), ('like', 30), ('back', 29), ('one', 29), ('angela', 26), ('go', 26), ('finds', 25), ('looking', 25), ('girl', 24)]
# ...
# Concordance of 'Begins':
# Displaying 25 of 38 matches:
# nd them. girl: yeah, you too. james begins to walk towards the graveyard exit.
#  next to a dead body. as the figure begins to walk towards james, he picks up
# ets down on his hands and knees and begins reaching out towards the key. he is
# ind my mama... angela stands up and begins walking towards the door. james: sh
# ness. the little girl stands up and begins to walk away. little girl: you didn
# james: sorry, i was confused. james begins to walk away from maria in the dire
# place’, huh? i’ll bet it was. james begins to walk away and maria reaches out
# ...

# %%
with open("../sources/jacobs-ladder-script.txt") as file2:
    raw_text = file2.read()
    tokens = raw_text.split()
    tokens = [w.lower() for w in tokens]
    # text object
    textObj = nltk.Text(tokens)

    #nltk.download('stopwords')
    stopwords = nltk.corpus.stopwords.words('english')
    filtered_tokens = [w for w in tokens if w.isalpha() and w not in stopwords]

    fdist = FreqDist(filtered_tokens)
    print(fdist)
    print(fdist.most_common(20))
    print(80*"=")
    print(f"Concordance of 'Begins':")
    textObj.concordance("begins")
    # check verbs with pos
# Out:
# <FreqDist with 3319 samples and 12725 outcomes>
# [('jacob', 919), ('jezzie', 296), ('like', 97), ('back', 82), ('michael', 82), ('eyes', 76), ('one', 73), ('paul', 70), ('suddenly', 69), ('looks', 67), ('see', 65), ('get', 63), ('know', 63), ('louis', 59), ('stares', 53), ('begins', 51), ('around', 51), ('turns', 49), ('day', 49), ('reaches', 48)]
# ...
# Concordance of 'Begins':
# Displaying 25 of 51 matches:
# l the air rushes from his lungs. he begins gasping and hyperventilating. his e
# into all- out panic. suddenly frank begins howling. he lunges for his bayonet
#  sides. suddenly paul flips out. he begins screaming uncontrollably, ripping a
#  "the stranger" by albert camus. he begins reading. another station blurs by.
# only sign of life in him. the train begins to slow down. jacob peers out of th
#  reaches for another girder when it begins to vibrate. two pinpoints of light
# hotos of his two other boys. jezzie begins shoving the remaining pictures back
# ...
