# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
base_url = "https://www.scripts.com/script/mulholland_drive_14210"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# %%
# stored line by line
with open("../../text-files/mul-scrape.txt", "w") as f:
    for page_num in range(0, 5):
        # Current page url
        if page_num == 0:
            url = base_url
        else:
            url = f"{base_url}{page_num}"
        print(f"Attempting Scrape on Page: {page_num}")
        
        # Response request
        response = requests.get(url, headers=headers)

        # Telemetry
        if response.status_code != 200:
            print(f"Failure! Status Code: {response.status_code}")
            break
        else:
            print(f"Success! Status Code: {response.status_code}")

        # Parse content for page
        tree = BeautifulSoup(response.content, "html.parser")

        container = tree.find("div", id="disp-quote-body")
        for script in container:
            print(script.get_text(strip=True))
            f.write(script.get_text(strip=True) + "\n")

        time.sleep(1)

#print(scrape_pages(0, 5))
#scrape_pages(0,5)
# Out:
# Attempting Scrape on Page: 0
# Success! Status Code: 200
# What are you doing?
# We don't stop here!
# Get out of the car.
# The boysfoundthis...
# on thefloorin back
# of the Caddy.
# Yeah, theyshowedme.
# Could be unrelated.
# Could be.
# Any ofthosedead kids wearin'
# pearl earrings?
# No.Couldbe someone's missin' maybe.
# That's what I'm thinkin'.
# Just one more bagafterthat.
# I justwantedto come here.
# To Winkie's?
# This Winkie's.
# Okay.
# Why this Winkie's?
# It's kind of embarrassing...
# Go ahead.
# I had adreamaboutthis place.
# Oh boy.
# You see what I mean?
# Okay, so you had adreamaboutthis place.
# Tell me.
# Well...
# it's thesecondone I've had...
# but they are both the same...
# theystartout that I'm in here but...
# it's not day or night.
# It'skindahalf night, you know?
# but it
# looks just like this...
# except for the light.
# And I'mscaredlike I can't tell ya.
# Of all people,
# you'restandingrightover there...
# by that counter.
# You're in both dreams
# ...
