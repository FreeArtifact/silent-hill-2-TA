# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
base_url = "https://www.scripts.com/script/mulholland_drive_14210"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

# %%
# stored line by line
with open("../../text-files/mul-scrape.txt", "w") as f:
    for page_num in range(0, 6):
        # Current page url
        if page_num == 0:
            url = base_url
        else:
            url = f"{base_url}/{page_num}"
        print(f"Attempting Scrape on Page: {page_num} and {url}")
        
        # Response request
        response = requests.get(url, headers=headers)

        # Telemetry
        if response.status_code != 200:
            print(f"Failure! Status Code: {response.status_code}")
            break
        else:
            print(f"Success! Status Code: {response.status_code}")

        # Parse content for page
        tree = BeautifulSoup(response.content, "html.parser")

        container = tree.find(id="disp-quote-body")
        for tag in container:
            #print(tag.text)
            f.write(tag.text + "\n")

        time.sleep(1)

#print(scrape_pages(0, 5))
#scrape_pages(0,5)
# Out:
# Attempting Scrape on Page: 0 and https://www.scripts.com/script/mulholland_drive_14210
# Success! Status Code: 200
# Attempting Scrape on Page: 1 and https://www.scripts.com/script/mulholland_drive_14210/1
# Success! Status Code: 200
# Attempting Scrape on Page: 2 and https://www.scripts.com/script/mulholland_drive_14210/2
# Success! Status Code: 200
# Attempting Scrape on Page: 3 and https://www.scripts.com/script/mulholland_drive_14210/3
# Success! Status Code: 200
# Attempting Scrape on Page: 4 and https://www.scripts.com/script/mulholland_drive_14210/4
# Success! Status Code: 200
# Attempting Scrape on Page: 5 and https://www.scripts.com/script/mulholland_drive_14210/5
# Success! Status Code: 200
